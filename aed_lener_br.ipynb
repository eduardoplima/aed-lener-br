# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoplima/aed-lener-br/blob/main/aed_lener_br.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Configuração do ambiente

# %%
import pandas as pd

# %%
def parse_conll(filepath):
    sentences = []
    sentence = []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            if line.strip() == '':
                if sentence:
                    sentences.append(sentence)
                    sentence = []
            else:
                parts = line.strip().split()
                if len(parts) >= 2:
                    token, label = parts[0], parts[-1]
                    sentence.append((token, label))
        if sentence:
            sentences.append(sentence)
    return sentences

train_data = parse_conll('train.conll')
test_data = parse_conll('test.conll')

# %%
train_data
# Out:
# [[('EMENTA', 'O'),
#   (':', 'O'),
#   ('APELAÇÃO', 'O'),
#   ('CÍVEL', 'O'),
#   ('-', 'O'),
#   ('AÇÃO', 'O'),
#   ('DE', 'O'),
#   ('INDENIZAÇÃO', 'O'),
#   ('POR', 'O'),
#   ('DANOS', 'O'),
#   ('MORAIS', 'O'),
#   ('-', 'O'),
#   ('PRELIMINAR', 'O'),
#   ('-', 'O'),
#   ('ARGUIDA', 'O'),
#   ('PELO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('EM', 'O'),
#   ('GRAU', 'O'),
#   ('RECURSAL', 'O'),
#   ('-', 'O'),
#   ('NULIDADE', 'O'),
#   ('-', 'O'),
#   ('AUSÊNCIA', 'O'),
#   ('DE', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('PARQUET', 'O'),
#   ('NA', 'O'),
#   ('INSTÂNCIA', 'O'),
#   ('A', 'O'),
#   ('QUO', 'O'),
#   ('-', 'O'),
#   ('PRESENÇA', 'O'),
#   ('DE', 'O'),
#   ('INCAPAZ', 'O'),
#   ('-', 'O'),
#   ('PREJUÍZO', 'O'),
#   ('EXISTENTE', 'O'),
#   ('-', 'O'),
#   ('PRELIMINAR', 'O'),
#   ('ACOLHIDA', 'O'),
#   ('-', 'O'),
#   ('NULIDADE', 'O'),
#   ('RECONHECIDA', 'O'),
#   ('.', 'O')],
#  [('-', 'O'),
#   ('O', 'O'),
#   ('art', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('178', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('II', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('CPC', 'I-LEGISLACAO'),
#   ('prescreve', 'O'),
#   ('que', 'O'),
#   ('compete', 'O'),
#   ('ao', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('intervir', 'O'),
#   ('nas', 'O'),
#   ('causas', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('há', 'O'),
#   ('interesses', 'O'),
#   ('de', 'O'),
#   ('incapazes', 'O'),
#   (',', 'O'),
#   ('dispondo', 'O'),
#   ('o', 'O'),
#   ('art', 'O'),
#   ('.', 'O'),
#   ('279', 'O'),
#   ('do', 'O'),
#   ('mesmo', 'O'),
#   ('diploma', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('será', 'O'),
#   ('nulo', 'O'),
#   ('quando', 'O'),
#   ('o', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('não', 'O'),
#   ('for', 'O'),
#   ('intimado', 'O'),
#   ('para', 'O'),
#   ('acompanhar', 'O'),
#   ('o', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('deve', 'O'),
#   ('intervir', 'O'),
#   ('.', 'O')],
#  [('-', 'O'),
#   ('Tratando-se', 'O'),
#   ('de', 'O'),
#   ('ação', 'O'),
#   ('indenizatória', 'O'),
#   ('ajuizada', 'O'),
#   ('por', 'O'),
#   ('pessoa', 'O'),
#   ('incapaz', 'O'),
#   (',', 'O'),
#   ('é', 'O'),
#   ('obrigatória', 'O'),
#   ('a', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('na', 'O'),
#   ('condição', 'O'),
#   ('de', 'O'),
#   ('fiscal', 'O'),
#   ('da', 'O'),
#   ('ordem', 'O'),
#   ('jurídica', 'O'),
#   ('.', 'O')],
#  [('-', 'O'),
#   ('Tendo', 'O'),
#   ('o', 'O'),
#   ('vício', 'O'),
#   ('sido', 'O'),
#   ('arguido', 'O'),
#   ('pelo', 'O'),
#   ('Parquet', 'O'),
#   ('nesta', 'O'),
#   ('instância', 'O'),
#   ('recursal', 'O'),
#   (',', 'O'),
#   ('bem', 'O'),
#   ('como', 'O'),
#   ('diante', 'O'),
#   ('da', 'O'),
#   ('sentença', 'O'),
#   ('de', 'O'),
#   ('improcedência', 'O'),
#   ('do', 'O'),
#   ('pedido', 'O'),
#   ('com', 'O'),
#   ('base', 'O'),
#   ('na', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('comprovação', 'O'),
#   ('dos', 'O'),
#   ('alegados', 'O'),
#   ('danos', 'O'),
#   ('morais', 'O'),
#   (',', 'O'),
#   ('impõe-se', 'O'),
#   ('o', 'O'),
#   ('reconhecimento', 'O'),
#   ('da', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('forma', 'O'),
#   ('a', 'O'),
#   ('permitir', 'O'),
#   ('ao', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('intervir', 'O'),
#   ('efetivamente', 'O'),
#   ('no', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('primeiro', 'O'),
#   ('grau', 'O'),
#   ('.', 'O')],
#  [('-', 'O'),
#   ('Preliminar', 'O'),
#   ('acolhida', 'O'),
#   ('para', 'O'),
#   ('reconhecer', 'O'),
#   ('a', 'O'),
#   ('nulidade', 'O'),
#   ('da', 'O'),
#   ('sentença', 'O'),
#   ('.', 'O')],
#  [('V.v', 'O'),
#   ('APELAÇÃO', 'O'),
#   ('CÍVEL', 'O'),
#   ('-', 'O'),
#   ('NULIDADE', 'O'),
#   ('PROCESSUAL', 'O'),
#   ('-', 'O'),
#   ('INTIMAÇÃO', 'O'),
#   ('DO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('-', 'O'),
#   ('INCAPAZ', 'O'),
#   ('ACOMPANHADA', 'O'),
#   ('DE', 'O'),
#   ('REPRESENTANTE', 'O'),
#   ('LEGAL', 'O'),
#   ('E', 'O'),
#   ('DE', 'O'),
#   ('ADVOGADO', 'O'),
#   ('-', 'O'),
#   ('EXERCÍCIO', 'O'),
#   ('DO', 'O'),
#   ('CONTRADITÓRIO', 'O'),
#   ('E', 'O'),
#   ('DA', 'O'),
#   ('AMPLA', 'O'),
#   ('DEFESA', 'O'),
#   ('-', 'O'),
#   ('AUSÊNCIA', 'O'),
#   ('DE', 'O'),
#   ('PREJUÍZOS', 'O'),
#   ('-', 'O'),
#   ('VÍCIO', 'O'),
#   ('AFASTADO', 'O'),
#   ('-', 'O'),
#   ('IMPROCEDÊNCIA', 'O'),
#   ('DO', 'O'),
#   ('PEDIDO', 'O'),
#   ('-', 'O'),
#   ('INEXISTÊNCIA', 'O'),
#   ('DE', 'O'),
#   ('PROVA', 'O'),
#   ('QUANTO', 'O'),
#   ('AO', 'O'),
#   ('FATO', 'O'),
#   ('CONSTITUTIVO', 'O'),
#   ('DO', 'O'),
#   ('DIREITO', 'O'),
#   ('.', 'O')],
#  [('RECURSO', 'O'), ('DESPROVIDO', 'O'), ('.', 'O')],
#  [('I', 'O'), ('.', 'O')],
#  [('É', 'O'),
#   ('entendimento', 'O'),
#   ('pacificado', 'O'),
#   ('que', 'O'),
#   ('``', 'O'),
#   ('a', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('nos', 'O'),
#   ('processos', 'O'),
#   ('que', 'O'),
#   ('envolvam', 'O'),
#   ('interesse', 'O'),
#   ('de', 'O'),
#   ('incapaz', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('motiva', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('ao', 'O'),
#   ('mesmo', 'O'),
#   ('tempo', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('justifica', 'O'),
#   ('na', 'O'),
#   ('possibilidade', 'O'),
#   ('de', 'O'),
#   ('desequilíbrio', 'O'),
#   ('da', 'O'),
#   ('relação', 'O'),
#   ('jurídica', 'O'),
#   ('e', 'O'),
#   ('no', 'O'),
#   ('eventual', 'O'),
#   ('comprometimento', 'O'),
#   ('do', 'O'),
#   ('contraditório', 'O'),
#   ('em', 'O'),
#   ('função', 'O'),
#   ('da', 'O'),
#   ('existência', 'O'),
#   ('da', 'O'),
#   ('parte', 'O'),
#   ('vulnerável', 'O'),
#   ("''", 'O'),
#   ('(', 'O'),
#   ('STJ', 'B-ORGANIZACAO'),
#   (',', 'O'),
#   ('REsp', 'B-JURISPRUDENCIA'),
#   ('n', 'I-JURISPRUDENCIA'),
#   ('.', 'I-JURISPRUDENCIA'),
#   ('1694984/MS', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'O'),
#   ('LUIS', 'B-PESSOA'),
#   ('FELIPE', 'I-PESSOA'),
#   ('SALOMÃO', 'I-PESSOA'),
#   (',', 'O'),
#   ('QUARTA', 'B-ORGANIZACAO'),
#   ('TURMA', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgado', 'O'),
#   ('em', 'O'),
#   ('14/11/2017', 'B-TEMPO'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('01/02/2018', 'B-TEMPO'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('II', 'O'), ('.', 'O')],
#  [('Verificando-se', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('incapaz', 'O'),
#   ('foi', 'O'),
#   ('acompanhada', 'O'),
#   ('de', 'O'),
#   ('seu', 'O'),
#   ('representante', 'O'),
#   ('legal', 'O'),
#   (',', 'O'),
#   ('bem', 'O'),
#   ('como', 'O'),
#   ('por', 'O'),
#   ('Advogado', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('qual', 'O'),
#   ('exerceu', 'O'),
#   ('com', 'O'),
#   ('regularidade', 'O'),
#   ('o', 'O'),
#   ('contraditório', 'O'),
#   ('e', 'O'),
#   ('a', 'O'),
#   ('ampla', 'O'),
#   ('defesa', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('parquet', 'O'),
#   ('não', 'O'),
#   ('se', 'O'),
#   ('erige', 'O'),
#   ('em', 'O'),
#   ('vício', 'O'),
#   ('suficiente', 'O'),
#   ('para', 'O'),
#   ('macular', 'O'),
#   ('de', 'O'),
#   ('nulidade', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('.', 'O')],
#  [('III', 'O'), ('.', 'O')],
#  [('Saliente-se', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('fato', 'O'),
#   ('da', 'O'),
#   ('``', 'O'),
#   ('improcedência', 'O'),
#   ('do', 'O'),
#   ('pedido', 'O'),
#   ("''", 'O'),
#   ('indenizatório', 'O'),
#   ('decorreu', 'O'),
#   ('do', 'O'),
#   ('fato', 'O'),
#   ('da', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('prova', 'O'),
#   ('de', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('atraso', 'O'),
#   ('na', 'O'),
#   ('entrega', 'O'),
#   ('da', 'O'),
#   ('``', 'O'),
#   ('carteira', 'O'),
#   ('de', 'O'),
#   ('saúde', 'O'),
#   ("''", 'O'),
#   ('pelo', 'O'),
#   ('plano', 'O'),
#   ('de', 'O'),
#   ('saúde', 'O'),
#   ('teria', 'O'),
#   ('impedido/dificultado', 'O'),
#   ('a', 'O'),
#   ('consulta', 'O'),
#   ('médica', 'O'),
#   (';', 'O'),
#   ('aliás', 'O'),
#   (',', 'O'),
#   ('inexiste', 'O'),
#   ('prova', 'O'),
#   (',', 'O'),
#   ('também', 'O'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('que', 'O'),
#   ('havia', 'O'),
#   ('consulta', 'O'),
#   ('médica', 'O'),
#   ('agendada', 'O'),
#   (',', 'O'),
#   ('sem', 'O'),
#   ('contar', 'O'),
#   ('que', 'O'),
#   ('é', 'O'),
#   ('sabido', 'O'),
#   ('que', 'O'),
#   ('este', 'O'),
#   ('fato', 'O'),
#   ('não', 'O'),
#   ('obstaculiza', 'O'),
#   ('a', 'O'),
#   ('consulta', 'O'),
#   (',', 'O'),
#   ('pois', 'O'),
#   ('basta', 'O'),
#   ('um', 'O'),
#   ('contato', 'O'),
#   ('com', 'O'),
#   ('a', 'O'),
#   ('operadora', 'O'),
#   ('do', 'O'),
#   ('plano', 'O'),
#   ('para', 'O'),
#   ('que', 'O'),
#   ('haja', 'O'),
#   ('a', 'O'),
#   ('liberação', 'O'),
#   ('do', 'O'),
#   ('atendimento', 'O'),
#   ('.', 'O')],
#  [('IV', 'O'),
#   ('.', 'O'),
#   ('Nulidade', 'O'),
#   ('afastada', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('no', 'O'),
#   ('mérito', 'O'),
#   (',', 'O'),
#   ('pelo', 'O'),
#   ('desprovimento', 'O'),
#   ('do', 'O'),
#   ('recurso', 'O'),
#   ('.', 'O')],
#  [('APELAÇÃO', 'B-JURISPRUDENCIA'),
#   ('CÍVEL', 'I-JURISPRUDENCIA'),
#   ('Nº', 'I-JURISPRUDENCIA'),
#   ('1.0024.13.385589-0/001', 'I-JURISPRUDENCIA'),
#   ('-', 'O'),
#   ('COMARCA', 'B-LOCAL'),
#   ('DE', 'I-LOCAL'),
#   ('BELO', 'I-LOCAL'),
#   ('HORIZONTE', 'I-LOCAL'),
#   ('-', 'O'),
#   ('APELANTE', 'O'),
#   ('(', 'O'),
#   ('S', 'O'),
#   (')', 'O'),
#   (':', 'O'),
#   ('REBECCA', 'B-PESSOA'),
#   ('DE', 'I-PESSOA'),
#   ('AGUIAR', 'I-PESSOA'),
#   ('LACERDA', 'I-PESSOA'),
#   ('REPDO', 'I-PESSOA'),
#   ('(', 'O'),
#   ('A', 'O'),
#   (')', 'O'),
#   ('PELO', 'O'),
#   ('(', 'O'),
#   ('A', 'O'),
#   (')', 'O'),
#   ('CURADOR', 'O'),
#   ('(', 'O'),
#   ('A', 'O'),
#   (')', 'O'),
#   ('SARA', 'B-PESSOA'),
#   ('GONÇALVES', 'I-PESSOA'),
#   ('DE', 'I-PESSOA'),
#   ('AGUIAR', 'I-PESSOA'),
#   ('-', 'O'),
#   ('APELADO', 'O'),
#   ('(', 'O'),
#   ('A', 'O'),
#   (')', 'O'),
#   ('(', 'O'),
#   ('S', 'O'),
#   (')', 'O'),
#   (':', 'O'),
#   ('UNIMED', 'B-ORGANIZACAO'),
#   ('RIO', 'I-ORGANIZACAO'),
#   ('COOPERATIVA', 'I-ORGANIZACAO'),
#   ('DE', 'I-ORGANIZACAO'),
#   ('TRABALHO', 'I-ORGANIZACAO'),
#   ('MÉDICO', 'I-ORGANIZACAO'),
#   ('DO', 'I-ORGANIZACAO'),
#   ('RIO', 'I-ORGANIZACAO'),
#   ('DE', 'I-ORGANIZACAO'),
#   ('JANEIRO', 'I-ORGANIZACAO'),
#   ('LTDA', 'I-ORGANIZACAO'),
#   ('A', 'O'),
#   ('C', 'O'),
#   ('Ó', 'O'),
#   ('R', 'O'),
#   ('D', 'O'),
#   ('Ã', 'O'),
#   ('O', 'O'),
#   ('Vistos', 'O'),
#   ('etc.', 'O'),
#   (',', 'O'),
#   ('acorda', 'O'),
#   (',', 'O'),
#   ('em', 'O'),
#   ('Turma', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('10ª', 'B-ORGANIZACAO'),
#   ('CÂMARA', 'I-ORGANIZACAO'),
#   ('CÍVEL', 'I-ORGANIZACAO'),
#   ('do', 'I-ORGANIZACAO'),
#   ('Tribunal', 'I-ORGANIZACAO'),
#   ('de', 'I-ORGANIZACAO'),
#   ('Justiça', 'I-ORGANIZACAO'),
#   ('do', 'I-ORGANIZACAO'),
#   ('Estado', 'I-ORGANIZACAO'),
#   ('de', 'I-ORGANIZACAO'),
#   ('Minas', 'I-ORGANIZACAO'),
#   ('Gerais', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('na', 'O'),
#   ('conformidade', 'O'),
#   ('da', 'O'),
#   ('ata', 'O'),
#   ('dos', 'O'),
#   ('julgamentos', 'O'),
#   (',', 'O'),
#   ('em', 'O'),
#   ('ACOLHER', 'O'),
#   ('A', 'O'),
#   ('PRELIMINAR', 'O'),
#   ('DE', 'O'),
#   ('NULIDADE', 'O'),
#   ('DO', 'O'),
#   ('FEITO', 'O'),
#   ('ARGUIDA', 'O'),
#   ('PELO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('CASSAR', 'O'),
#   ('A', 'O'),
#   ('SENTENÇA', 'O'),
#   (',', 'O'),
#   ('PARA', 'O'),
#   ('PERMITIR', 'O'),
#   ('A', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('REPRESENTANTE', 'O'),
#   ('DO', 'O'),
#   ('PARQUET', 'B-ORGANIZACAO'),
#   ('EM', 'O'),
#   ('PRIMEIRO', 'O'),
#   ('GRAU', 'O'),
#   (',', 'O'),
#   ('VENCIDO', 'O'),
#   ('O', 'O'),
#   ('SEGUNDO', 'O'),
#   ('VOGAL', 'O'),
#   ('.', 'O')],
#  [('DESA', 'O'), ('.', 'O')],
#  [('MARIÂNGELA', 'B-PESSOA'),
#   ('MEYER', 'I-PESSOA'),
#   ('RELATORA', 'O'),
#   ('.', 'O')],
#  [('DESA', 'O'), ('.', 'O')],
#  [('MARIÂNGELA', 'B-PESSOA'),
#   ('MEYER', 'I-PESSOA'),
#   ('(', 'O'),
#   ('RELATORA', 'O'),
#   (')', 'O'),
#   ('V', 'O'),
#   ('O', 'O'),
#   ('T', 'O'),
#   ('O', 'O'),
#   ('Trata-se', 'O'),
#   ('de', 'O'),
#   ('apelação', 'O'),
#   ('cível', 'O'),
#   ('interposta', 'O'),
#   ('por', 'O'),
#   ('REBECCA', 'B-PESSOA'),
#   ('DE', 'I-PESSOA'),
#   ('AGUIAR', 'I-PESSOA'),
#   ('LACERDA', 'I-PESSOA'),
#   ('contra', 'O'),
#   ('a', 'O'),
#   ('sentença', 'O'),
#   ('de', 'O'),
#   ('fls', 'O'),
#   ('.', 'O'),
#   ('138/140', 'O'),
#   (',', 'O'),
#   ('prolatada', 'O'),
#   ('pelo', 'O'),
#   ('MM', 'O'),
#   ('.', 'O')],
#  [('Juiz', 'O'),
#   ('da', 'O'),
#   ('10ª', 'B-ORGANIZACAO'),
#   ('Vara', 'I-ORGANIZACAO'),
#   ('Cível', 'I-ORGANIZACAO'),
#   ('desta', 'I-ORGANIZACAO'),
#   ('Capital', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('nos', 'O'),
#   ('autos', 'O'),
#   ('da', 'O'),
#   ('Ação', 'O'),
#   ('de', 'O'),
#   ('Indenização', 'O'),
#   ('por', 'O'),
#   ('Danos', 'O'),
#   ('Morais', 'O'),
#   ('ajuizada', 'O'),
#   ('em', 'O'),
#   ('face', 'O'),
#   ('de', 'O'),
#   ('UNIMED', 'B-ORGANIZACAO'),
#   ('RIO', 'I-ORGANIZACAO'),
#   ('COOPERATIVA', 'I-ORGANIZACAO'),
#   ('DE', 'I-ORGANIZACAO'),
#   ('TRABALHO', 'I-ORGANIZACAO'),
#   ('MÉDICO', 'I-ORGANIZACAO'),
#   ('DO', 'I-ORGANIZACAO'),
#   ('RIO', 'I-ORGANIZACAO'),
#   ('DE', 'I-ORGANIZACAO'),
#   ('JANEIRO', 'I-ORGANIZACAO'),
#   ('LTDA', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgou', 'O'),
#   ('improcedentes', 'O'),
#   ('os', 'O'),
#   ('pedidos', 'O'),
#   ('exordiais', 'O'),
#   (',', 'O'),
#   ('condenando', 'O'),
#   ('a', 'O'),
#   ('requerente', 'O'),
#   ('ao', 'O'),
#   ('pagamento', 'O'),
#   ('das', 'O'),
#   ('custas', 'O'),
#   ('e', 'O'),
#   ('honorários', 'O'),
#   ('de', 'O'),
#   ('sucumbência', 'O'),
#   (',', 'O'),
#   ('arbitrados', 'O'),
#   ('em', 'O'),
#   ('10', 'O'),
#   ('%', 'O'),
#   ('sobre', 'O'),
#   ('o', 'O'),
#   ('valor', 'O'),
#   ('atribuído', 'O'),
#   ('à', 'O'),
#   ('causa', 'O'),
#   ('.', 'O')],
#  [('Inconformada', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('apelante', 'O'),
#   ('afirma', 'O'),
#   ('que', 'O'),
#   ('em', 'O'),
#   ('virtude', 'O'),
#   ('da', 'O'),
#   ('falha', 'O'),
#   ('na', 'O'),
#   ('prestação', 'O'),
#   ('de', 'O'),
#   ('serviço', 'O'),
#   ('da', 'O'),
#   ('apelada', 'O'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('não', 'O'),
#   ('emitiu', 'O'),
#   ('a', 'O'),
#   ('carteira', 'O'),
#   ('da', 'O'),
#   ('requerente', 'O'),
#   (',', 'O'),
#   ('esta', 'O'),
#   ('teve', 'O'),
#   ('recusado', 'O'),
#   ('tratamento', 'O'),
#   ('em', 'O'),
#   ('hospital', 'O'),
#   ('credenciado', 'O'),
#   ('pela', 'O'),
#   ('recorrida', 'O'),
#   ('.', 'O')],
#  [('Defende', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('recorrida', 'O'),
#   ('não', 'O'),
#   ('comprovou', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('falha', 'O'),
#   ('decorreu', 'O'),
#   ('de', 'O'),
#   ('greve', 'O'),
#   ('dos', 'O'),
#   ('Correios', 'B-ORGANIZACAO'),
#   (',', 'O'),
#   ('tampouco', 'O'),
#   ('demonstrou', 'O'),
#   ('ter', 'O'),
#   ('adotado', 'O'),
#   ('providências', 'O'),
#   ('no', 'O'),
#   ('sentido', 'O'),
#   ('de', 'O'),
#   ('evitar', 'O'),
#   ('o', 'O'),
#   ('dano', 'O'),
#   ('.', 'O')],
#  [('Sustenta', 'O'),
#   ('ser', 'O'),
#   ('portadora', 'O'),
#   ('de', 'O'),
#   ('Síndrome', 'O'),
#   ('de', 'O'),
#   ('Down', 'O'),
#   ('e', 'O'),
#   ('já', 'O'),
#   ('foi', 'O'),
#   ('submetida', 'O'),
#   ('a', 'O'),
#   ('2', 'O'),
#   ('cirurgias', 'O'),
#   ('cardíacas', 'O'),
#   (',', 'O'),
#   ('necessitando', 'O'),
#   ('de', 'O'),
#   ('realizar', 'O'),
#   ('acompanhamento', 'O'),
#   ('com', 'O'),
#   ('cardiologista', 'O'),
#   ('.', 'O')],
#  [('Aduz', 'O'),
#   ('que', 'O'),
#   ('havia', 'O'),
#   ('marcado', 'O'),
#   ('consulta', 'O'),
#   ('com', 'O'),
#   ('mais', 'O'),
#   ('de', 'O'),
#   ('um', 'O'),
#   ('mês', 'O'),
#   ('de', 'O'),
#   ('antecedência', 'O'),
#   (',', 'O'),
#   ('para', 'O'),
#   ('se', 'O'),
#   ('submeter', 'O'),
#   ('a', 'O'),
#   ('acompanhamento', 'O'),
#   ('de', 'O'),
#   ('rotina', 'O'),
#   (',', 'O'),
#   ('todavia', 'O'),
#   (',', 'O'),
#   ('teve', 'O'),
#   ('o', 'O'),
#   ('atendimento', 'O'),
#   ('negado', 'O'),
#   ('pelo', 'O'),
#   ('fato', 'O'),
#   ('de', 'O'),
#   ('não', 'O'),
#   ('possuir', 'O'),
#   ('a', 'O'),
#   ('carteira', 'O'),
#   ('do', 'O'),
#   ('novo', 'O'),
#   ('plano', 'O'),
#   ('e', 'O'),
#   ('seu', 'O'),
#   ('antigo', 'O'),
#   ('estava', 'O'),
#   ('cancelado', 'O'),
#   ('.', 'O')],
#  [('Reitera', 'O'),
#   ('que', 'O'),
#   ('não', 'O'),
#   ('se', 'O'),
#   ('trata', 'O'),
#   ('de', 'O'),
#   ('mero', 'O'),
#   ('aborrecimento', 'O'),
#   ('.', 'O')],
#  [('Requer', 'O'),
#   ('seja', 'O'),
#   ('dado', 'O'),
#   ('provimento', 'O'),
#   ('ao', 'O'),
#   ('recurso', 'O'),
#   (',', 'O'),
#   ('para', 'O'),
#   ('reformar', 'O'),
#   ('a', 'O'),
#   ('sentença', 'O'),
#   ('e', 'O'),
#   ('julgar', 'O'),
#   ('procedente', 'O'),
#   ('o', 'O'),
#   ('pedido', 'O'),
#   ('inicial', 'O'),
#   (',', 'O'),
#   ('condenando', 'O'),
#   ('a', 'O'),
#   ('requerida', 'O'),
#   ('ao', 'O'),
#   ('pagamento', 'O'),
#   ('de', 'O'),
#   ('indenização', 'O'),
#   ('por', 'O'),
#   ('danos', 'O'),
#   ('morais', 'O'),
#   ('.', 'O')],
#  [('Contrarrazões', 'O'),
#   ('recursais', 'O'),
#   ('apresentadas', 'O'),
#   ('às', 'O'),
#   ('fls', 'O'),
#   ('.', 'O'),
#   ('148/153', 'O'),
#   (',', 'O'),
#   ('defendendo', 'O'),
#   ('não', 'O'),
#   ('ter', 'O'),
#   ('havido', 'O'),
#   ('a', 'O'),
#   ('prática', 'O'),
#   ('de', 'O'),
#   ('qualquer', 'O'),
#   ('ato', 'O'),
#   ('ilícito', 'O'),
#   ('que', 'O'),
#   ('justifique', 'O'),
#   ('o', 'O'),
#   ('pedido', 'O'),
#   ('indenizatório', 'O'),
#   ('.', 'O')],
#  [('Argumenta', 'O'),
#   ('que', 'O'),
#   ('não', 'O'),
#   ('houve', 'O'),
#   ('comprovação', 'O'),
#   ('de', 'O'),
#   ('violação', 'O'),
#   ('a', 'O'),
#   ('direito', 'O'),
#   ('da', 'O'),
#   ('personalidade', 'O'),
#   ('da', 'O'),
#   ('apelante', 'O'),
#   (',', 'O'),
#   ('tratando-se', 'O'),
#   ('de', 'O'),
#   ('mero', 'O'),
#   ('descumprimento', 'O'),
#   ('contratual', 'O'),
#   ('.', 'O')],
#  [('Pugna', 'O'),
#   ('seja', 'O'),
#   ('negado', 'O'),
#   ('provimento', 'O'),
#   ('ao', 'O'),
#   ('recurso', 'O'),
#   ('.', 'O')],
#  [('Manifestou-se', 'O'),
#   ('o', 'O'),
#   ('parquet', 'B-ORGANIZACAO'),
#   ('às', 'O'),
#   ('fls', 'O'),
#   ('.', 'O'),
#   ('159/160', 'O'),
#   (',', 'O'),
#   ('opinando', 'O'),
#   ('pela', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('virtude', 'O'),
#   ('da', 'O'),
#   ('falta', 'O'),
#   ('de', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('para', 'O'),
#   ('manifestar', 'O'),
#   ('no', 'O'),
#   ('presente', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('primeira', 'O'),
#   ('instância', 'O'),
#   ('.', 'O')],
#  [('Ressalta', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('apelante', 'O'),
#   ('é', 'O'),
#   ('portadora', 'O'),
#   ('de', 'O'),
#   ('Síndrome', 'O'),
#   ('de', 'O'),
#   ('Down', 'O'),
#   (',', 'O'),
#   ('sendo', 'O'),
#   ('interditada', 'O'),
#   ('e', 'O'),
#   ('curatelada', 'O'),
#   ('por', 'O'),
#   ('sua', 'O'),
#   ('genitora', 'O'),
#   (',', 'O'),
#   ('tornando', 'O'),
#   ('indispensável', 'O'),
#   ('a', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('MP', 'B-ORGANIZACAO'),
#   ('.', 'O')],
#  [('Destaca', 'O'),
#   ('que', 'O'),
#   ('houve', 'O'),
#   ('prejuízo', 'O'),
#   ('ao', 'O'),
#   ('incapaz', 'O'),
#   ('.', 'O')],
#  [('Pugna', 'O'),
#   ('seja', 'O'),
#   ('declarada', 'O'),
#   ('a', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   ('desde', 'O'),
#   ('o', 'O'),
#   ('momento', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('Representante', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('deveria', 'O'),
#   ('ter', 'O'),
#   ('sido', 'O'),
#   ('intimado', 'O'),
#   ('para', 'O'),
#   ('intervir', 'O'),
#   ('.', 'O')],
#  [('Relatado', 'O'),
#   (',', 'O'),
#   ('examino', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('ao', 'O'),
#   ('final', 'O'),
#   (',', 'O'),
#   ('decido', 'O'),
#   ('.', 'O')],
#  [('Recurso', 'O'),
#   ('próprio', 'O'),
#   (',', 'O'),
#   ('tempestivo', 'O'),
#   ('e', 'O'),
#   ('dispensado', 'O'),
#   ('o', 'O'),
#   ('preparo', 'O'),
#   (',', 'O'),
#   ('em', 'O'),
#   ('razão', 'O'),
#   ('da', 'O'),
#   ('justiça', 'O'),
#   ('gratuita', 'O'),
#   ('deferida', 'O'),
#   ('à', 'O'),
#   ('fl', 'O'),
#   ('.', 'O'),
#   ('19', 'O'),
#   ('.', 'O')],
#  [('Conheço', 'O'),
#   ('do', 'O'),
#   ('apelo', 'O'),
#   (',', 'O'),
#   ('presentes', 'O'),
#   ('os', 'O'),
#   ('demais', 'O'),
#   ('pressupostos', 'O'),
#   ('de', 'O'),
#   ('admissibilidade', 'O'),
#   ('.', 'O')],
#  [('Recebo', 'O'),
#   ('a', 'O'),
#   ('apelação', 'O'),
#   ('nos', 'O'),
#   ('termos', 'O'),
#   ('do', 'O'),
#   ('art', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('1.012', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('NCPC', 'I-LEGISLACAO'),
#   ('.', 'O')],
#  [('PRELIMINAR', 'O'),
#   ('NULIDADE', 'O'),
#   ('DO', 'O'),
#   ('FEITO', 'O'),
#   ('-', 'O'),
#   ('NECESSÁRIA', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('Como', 'O'),
#   ('visto', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('membro', 'O'),
#   ('do', 'O'),
#   ('Parquet', 'O'),
#   ('em', 'O'),
#   ('segundo', 'O'),
#   ('grau', 'O'),
#   ('suscitou', 'O'),
#   ('a', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   (',', 'O'),
#   ('tendo', 'O'),
#   ('em', 'O'),
#   ('vista', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('Representante', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('não', 'O'),
#   ('foi', 'O'),
#   ('intimado', 'O'),
#   ('para', 'O'),
#   ('se', 'O'),
#   ('manifestar', 'O'),
#   ('no', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('primeira', 'O'),
#   ('instância', 'O'),
#   (',', 'O'),
#   ('conquanto', 'O'),
#   ('a', 'O'),
#   ('parte', 'O'),
#   ('autora/apelante', 'O'),
#   ('seja', 'O'),
#   ('incapaz', 'O'),
#   ('.', 'O')],
#  [('Sobre', 'O'),
#   ('o', 'O'),
#   ('tema', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('art', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('178', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('II', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('CPC', 'I-LEGISLACAO'),
#   ('prescreve', 'O'),
#   ('que', 'O'),
#   ('compete', 'O'),
#   ('ao', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('intervir', 'O'),
#   ('nas', 'O'),
#   ('causas', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('há', 'O'),
#   ('interesses', 'O'),
#   ('de', 'O'),
#   ('incapazes', 'O'),
#   (',', 'O'),
#   ('dispondo', 'O'),
#   ('o', 'O'),
#   ('art', 'O'),
#   ('.', 'O'),
#   ('279', 'O'),
#   ('do', 'O'),
#   ('mesmo', 'O'),
#   ('diploma', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('será', 'O'),
#   ('nulo', 'O'),
#   ('quando', 'O'),
#   ('o', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('não', 'O'),
#   ('for', 'O'),
#   ('intimado', 'O'),
#   ('para', 'O'),
#   ('acompanhar', 'O'),
#   ('o', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('deve', 'O'),
#   ('intervir', 'O'),
#   ('.', 'O')],
#  [('Confira', 'O'),
#   ('a', 'O'),
#   ('redação', 'O'),
#   ('dos', 'O'),
#   ('dispositivos', 'O'),
#   ('legais', 'O'),
#   ('citados', 'O'),
#   (':', 'O'),
#   ("''", 'O'),
#   ('Art', 'O'),
#   ('.', 'O'),
#   ('178', 'O'),
#   ('.', 'O')],
#  [('O', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('será', 'O'),
#   ('intimado', 'O'),
#   ('para', 'O'),
#   (',', 'O'),
#   ('no', 'O'),
#   ('prazo', 'O'),
#   ('de', 'O'),
#   ('30', 'O'),
#   ('(', 'O'),
#   ('trinta', 'O'),
#   (')', 'O'),
#   ('dias', 'O'),
#   (',', 'O'),
#   ('intervir', 'O'),
#   ('como', 'O'),
#   ('fiscal', 'O'),
#   ('da', 'O'),
#   ('ordem', 'O'),
#   ('jurídica', 'O'),
#   ('nas', 'O'),
#   ('hipóteses', 'O'),
#   ('previstas', 'O'),
#   ('em', 'O'),
#   ('lei', 'O'),
#   ('ou', 'O'),
#   ('na', 'O'),
#   ('Constituição', 'B-LEGISLACAO'),
#   ('Federal', 'I-LEGISLACAO'),
#   ('e', 'O'),
#   ('nos', 'O'),
#   ('processos', 'O'),
#   ('que', 'O'),
#   ('envolvam', 'O'),
#   (':', 'O'),
#   ('I', 'O'),
#   ('-', 'O'),
#   ('interesse', 'O'),
#   ('público', 'O'),
#   ('ou', 'O'),
#   ('social', 'O'),
#   (';', 'O'),
#   ('II', 'O'),
#   ('-', 'O'),
#   ('interesse', 'O'),
#   ('de', 'O'),
#   ('incapaz', 'O'),
#   (';', 'O'),
#   ('(', 'O'),
#   ('...', 'O'),
#   (')', 'O'),
#   ('Art', 'O'),
#   ('.', 'O'),
#   ('279', 'O'),
#   ('.', 'O')],
#  [('É', 'O'),
#   ('nulo', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('quando', 'O'),
#   ('o', 'O'),
#   ('membro', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('não', 'O'),
#   ('for', 'O'),
#   ('intimado', 'O'),
#   ('a', 'O'),
#   ('acompanhar', 'O'),
#   ('o', 'O'),
#   ('feito', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('deva', 'O'),
#   ('intervir', 'O'),
#   ('.', 'O')],
#  [('§', 'O'),
#   ('1º', 'O'),
#   ('Se', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('tiver', 'O'),
#   ('tramitado', 'O'),
#   ('sem', 'O'),
#   ('conhecimento', 'O'),
#   ('do', 'O'),
#   ('membro', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('juiz', 'O'),
#   ('invalidará', 'O'),
#   ('os', 'O'),
#   ('atos', 'O'),
#   ('praticados', 'O'),
#   ('a', 'O'),
#   ('partir', 'O'),
#   ('do', 'O'),
#   ('momento', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('ele', 'O'),
#   ('deveria', 'O'),
#   ('ter', 'O'),
#   ('sido', 'O'),
#   ('intimado', 'O'),
#   ('.', 'O')],
#  [('§', 'O'),
#   ('2º', 'O'),
#   ('A', 'O'),
#   ('nulidade', 'O'),
#   ('só', 'O'),
#   ('pode', 'O'),
#   ('ser', 'O'),
#   ('decretada', 'O'),
#   ('após', 'O'),
#   ('a', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('se', 'O'),
#   ('manifestará', 'O'),
#   ('sobre', 'O'),
#   ('a', 'O'),
#   ('existência', 'O'),
#   ('ou', 'O'),
#   ('a', 'O'),
#   ('inexistência', 'O'),
#   ('de', 'O'),
#   ('prejuízo', 'O'),
#   ("''", 'O'),
#   ('.', 'O')],
#  [('No', 'O'),
#   ('caso', 'O'),
#   ('dos', 'O'),
#   ('autos', 'O'),
#   (',', 'O'),
#   ('foi', 'O'),
#   ('ajuizada', 'O'),
#   ('ação', 'O'),
#   ('de', 'O'),
#   ('indenização', 'O'),
#   ('por', 'O'),
#   ('danos', 'O'),
#   ('morais', 'O'),
#   ('em', 'O'),
#   ('razão', 'O'),
#   ('de', 'O'),
#   ('suposto', 'O'),
#   ('atraso', 'O'),
#   ('na', 'O'),
#   ('entrega', 'O'),
#   ('da', 'O'),
#   ('carteira', 'O'),
#   ('do', 'O'),
#   ('plano', 'O'),
#   ('de', 'O'),
#   ('saúde', 'O'),
#   ('da', 'O'),
#   ('recorrente/autora', 'O'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('teria', 'O'),
#   ('impedido', 'O'),
#   ('de', 'O'),
#   ('consultar', 'O'),
#   ('com', 'O'),
#   ('seu', 'O'),
#   ('médico', 'O'),
#   ('.', 'O')],
#  [('Ressalte-se', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('requerente', 'O'),
#   ('é', 'O'),
#   ('portadora', 'O'),
#   ('de', 'O'),
#   ('Síndrome', 'O'),
#   ('de', 'O'),
#   ('Down', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('consoante', 'O'),
#   ('se', 'O'),
#   ('extrai', 'O'),
#   ('do', 'O'),
#   ('documento', 'O'),
#   ('de', 'O'),
#   ('fl', 'O'),
#   ('.', 'O'),
#   ('10', 'O'),
#   (',', 'O'),
#   ('interditada', 'O'),
#   (',', 'O'),
#   ('sendo', 'O'),
#   ('representada', 'O'),
#   ('por', 'O'),
#   ('sua', 'O'),
#   ('genitora', 'O'),
#   ('Sara', 'B-PESSOA'),
#   ('Gonçalves', 'I-PESSOA'),
#   ('de', 'I-PESSOA'),
#   ('Aguiar', 'I-PESSOA'),
#   ('.', 'O')],
#  [('A', 'O'),
#   ('despeito', 'O'),
#   ('disso', 'O'),
#   (',', 'O'),
#   ('é', 'O'),
#   ('possível', 'O'),
#   ('perceber', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('tramitou', 'O'),
#   ('em', 'O'),
#   ('primeiro', 'O'),
#   ('grau', 'O'),
#   ('sem', 'O'),
#   ('a', 'O'),
#   ('intervenção', 'O'),
#   ('obrigatória', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('na', 'O'),
#   ('condição', 'O'),
#   ('de', 'O'),
#   ('fiscal', 'O'),
#   ('da', 'O'),
#   ('ordem', 'O'),
#   ('jurídica', 'O'),
#   ('.', 'O')],
#  [('Trata-se', 'O'),
#   ('de', 'O'),
#   ('causa', 'O'),
#   ('de', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   (',', 'O'),
#   ('sobretudo', 'O'),
#   (',', 'O'),
#   ('porque', 'O'),
#   ('alegado', 'O'),
#   ('pelo', 'O'),
#   ('Parquet', 'B-ORGANIZACAO'),
#   ('nesta', 'O'),
#   ('instância', 'O'),
#   ('recursal', 'O'),
#   (',', 'O'),
#   ('bem', 'O'),
#   ('como', 'O'),
#   ('diante', 'O'),
#   ('da', 'O'),
#   ('sentença', 'O'),
#   ('de', 'O'),
#   ('improcedência', 'O'),
#   ('do', 'O'),
#   ('pedido', 'O'),
#   ('com', 'O'),
#   ('base', 'O'),
#   ('na', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('comprovação', 'O'),
#   ('dos', 'O'),
#   ('alegados', 'O'),
#   ('danos', 'O'),
#   ('morais', 'O'),
#   ('.', 'O')],
#  [('É', 'O'),
#   ('imperativo', 'O'),
#   (',', 'O'),
#   ('pois', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('reconhecimento', 'O'),
#   ('da', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   (',', 'O'),
#   ('desde', 'O'),
#   ('a', 'O'),
#   ('fase', 'O'),
#   ('de', 'O'),
#   ('produção', 'O'),
#   ('de', 'O'),
#   ('provas', 'O'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('forma', 'O'),
#   ('a', 'O'),
#   ('permitir', 'O'),
#   ('ao', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('intervir', 'O'),
#   ('efetivamente', 'O'),
#   ('no', 'O'),
#   ('feito', 'O'),
#   (',', 'O'),
#   ('produzindo', 'O'),
#   ('provas', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('quiser', 'O'),
#   (',', 'O'),
#   ('assim', 'O'),
#   ('como', 'O'),
#   ('se', 'O'),
#   ('manifestar', 'O'),
#   ('sobre', 'O'),
#   ('o', 'O'),
#   ('mérito', 'O'),
#   ('da', 'O'),
#   ('demanda', 'O'),
#   ('.', 'O')],
#  [('Nesse', 'O'),
#   ('sentido', 'O'),
#   ('é', 'O'),
#   ('a', 'O'),
#   ('jurisprudência', 'O'),
#   ('pátria', 'O'),
#   ('mais', 'O'),
#   ('recente', 'O'),
#   (':', 'O'),
#   ("''", 'O'),
#   ('PROCESSUAL', 'O'),
#   ('CIVIL', 'O'),
#   ('.', 'O')],
#  [('AÇÃO', 'O'), ('DECLARATÓRIA', 'O'), ('.', 'O')],
#  [('DESAPROPRIAÇÃO', 'O'), ('.', 'O')],
#  [('REFORMA', 'O'), ('AGRÁRIA', 'O'), ('.', 'O')],
#  [('NECESSIDADE', 'O'),
#   ('DE', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('FEDERAL', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('ART', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('18', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('§', 'I-LEGISLACAO'),
#   ('2º', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('DA', 'I-LEGISLACAO'),
#   ('LC', 'I-LEGISLACAO'),
#   ('76/93', 'I-LEGISLACAO'),
#   ('.', 'O')],
#  [('NULIDADE', 'O'), ('.', 'O')],
#  [('PRECEDENTES', 'O'), ('.', 'O')],
#  [('1', 'O'), ('.', 'O')],
#  [('O', 'O'),
#   ('Superior', 'B-ORGANIZACAO'),
#   ('Tribunal', 'I-ORGANIZACAO'),
#   ('de', 'I-ORGANIZACAO'),
#   ('Justiça', 'I-ORGANIZACAO'),
#   ('entende', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('nas', 'O'),
#   ('Ações', 'O'),
#   ('de', 'O'),
#   ('Desapropriação', 'O'),
#   ('de', 'O'),
#   ('Imóvel', 'O'),
#   ('Rural', 'O'),
#   ('para', 'O'),
#   ('fins', 'O'),
#   ('de', 'O'),
#   ('Reforma', 'O'),
#   ('Agrária', 'O'),
#   ('é', 'O'),
#   ('obrigatória', 'O'),
#   (',', 'O'),
#   ('indisponível', 'O'),
#   ('e', 'O'),
#   ('inderrogável', 'O'),
#   (',', 'O'),
#   ('porquanto', 'O'),
#   ('presente', 'O'),
#   ('o', 'O'),
#   ('interesse', 'O'),
#   ('público', 'O'),
#   ('.', 'O')],
#  [('Assim', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('falta', 'O'),
#   ('de', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('MP', 'B-ORGANIZACAO'),
#   ('para', 'O'),
#   ('atuar', 'O'),
#   ('no', 'O'),
#   ('feito', 'O'),
#   ('como', 'O'),
#   ('fiscal', 'O'),
#   ('da', 'O'),
#   ('lei', 'O'),
#   ('é', 'O'),
#   ('vício', 'O'),
#   ('que', 'O'),
#   ('contamina', 'O'),
#   ('todos', 'O'),
#   ('os', 'O'),
#   ('atos', 'O'),
#   ('decisórios', 'O'),
#   ('a', 'O'),
#   ('partir', 'O'),
#   ('do', 'O'),
#   ('momento', 'O'),
#   ('processual', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('deveria', 'O'),
#   ('se', 'O'),
#   ('manifestar', 'O'),
#   ('.', 'O')],
#  [('Precedentes', 'O'),
#   (':', 'O'),
#   ('REsp', 'B-JURISPRUDENCIA'),
#   ('932.731/BA', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'O'),
#   ('Herman', 'B-PESSOA'),
#   ('Benjamin', 'I-PESSOA'),
#   (',', 'O'),
#   ('Segunda', 'B-ORGANIZACAO'),
#   ('Turma', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('31.8.2009', 'B-TEMPO'),
#   (';', 'O'),
#   ('REsp', 'B-JURISPRUDENCIA'),
#   ('1.061.852/PR', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'B-PESSOA'),
#   ('Benedito', 'I-PESSOA'),
#   ('Gonçalves', 'I-PESSOA'),
#   (',', 'O'),
#   ('Primeira', 'O'),
#   ('Turma', 'O'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('28.9.2009', 'B-TEMPO'),
#   (';', 'O'),
#   ('e', 'O'),
#   ('REsp', 'B-JURISPRUDENCIA'),
#   ('1.249.358/RJ', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'O'),
#   ('Mauro', 'B-PESSOA'),
#   ('Campbell', 'I-PESSOA'),
#   ('Marques', 'I-PESSOA'),
#   (',', 'O'),
#   ('Segunda', 'B-ORGANIZACAO'),
#   ('Turma', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('28.6.2013', 'B-TEMPO'),
#   ('.', 'O')],
#  [('3', 'O'),
#   ('.', 'O'),
#   ('Recurso', 'O'),
#   ('Especial', 'O'),
#   ('provido', 'O'),
#   ('.', 'O')],
#  [('(', 'O'),
#   ('REsp', 'B-JURISPRUDENCIA'),
#   ('1681249/SP', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'O'),
#   ('HERMAN', 'B-PESSOA'),
#   ('BENJAMIN', 'I-PESSOA'),
#   (',', 'O'),
#   ('SEGUNDA', 'B-ORGANIZACAO'),
#   ('TURMA', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgado', 'O'),
#   ('em', 'O'),
#   ('05/09/2017', 'B-TEMPO'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('13/09/2017', 'B-TEMPO'),
#   (')', 'O'),
#   ('EMENTA', 'O'),
#   (':', 'O'),
#   ('APELAÇÃO', 'O'),
#   ('CIVEL', 'O'),
#   ('.', 'O')],
#  [('AÇÃO', 'O'), ('DE', 'O'), ('COBRANÇA', 'O'), ('.', 'O')],
#  [('POLO', 'O'), ('PASSIVO', 'O'), ('.', 'O')],
#  [('MENOR', 'O'), ('IMPÚBERE', 'O'), ('.', 'O')],
#  [('AUSÊNCIA', 'O'),
#   ('DE', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('PEDIDO', 'O'),
#   ('INICIAL', 'O'),
#   ('JULGADO', 'O'),
#   ('PROCEDENTE', 'O'),
#   ('.', 'O')],
#  [('PREJUÍZO', 'O'), ('PARA', 'O'), ('O', 'O'), ('MENOR', 'O'), ('.', 'O')],
#  [('SENTENÇA', 'O'), ('CASSADA', 'O'), ('.', 'O')],
#  [('-', 'O'),
#   ('A', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('é', 'O'),
#   ('imprescindível', 'O'),
#   ('quando', 'O'),
#   ('há', 'O'),
#   ('interesse', 'O'),
#   ('de', 'O'),
#   ('menor', 'O'),
#   ('no', 'O'),
#   ('processo', 'O'),
#   (',', 'O'),
#   ('conforme', 'O'),
#   ('o', 'O'),
#   ('disposto', 'O'),
#   ('no', 'O'),
#   ('art', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('279', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('NCPC', 'I-LEGISLACAO'),
#   ('.', 'O')],
#  [('-', 'O'),
#   ('Intimada', 'O'),
#   ('a', 'O'),
#   ('Procuradoria-Geral', 'B-ORGANIZACAO'),
#   ('de', 'I-ORGANIZACAO'),
#   ('Justiça', 'I-ORGANIZACAO'),
#   ('nesta', 'O'),
#   ('Instância', 'O'),
#   ('Revisora', 'O'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('tendo', 'O'),
#   ('o', 'O'),
#   ('referido', 'O'),
#   ('órgão', 'O'),
#   ('alegado', 'O'),
#   ('a', 'O'),
#   ('existência', 'O'),
#   ('de', 'O'),
#   ('prejuízo', 'O'),
#   ('para', 'O'),
#   ('o', 'O'),
#   ('menor', 'O'),
#   (',', 'O'),
#   ('diante', 'O'),
#   ('da', 'O'),
#   ('sentença', 'O'),
#   ('de', 'O'),
#   ('procedência', 'O'),
#   ('do', 'O'),
#   ('pedido', 'O'),
#   ('inicial', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('medida', 'O'),
#   ('que', 'O'),
#   ('se', 'O'),
#   ('impõe', 'O'),
#   ('é', 'O'),
#   ('a', 'O'),
#   ('cassação', 'O'),
#   ('do', 'O'),
#   ('referido', 'O'),
#   ('``', 'O'),
#   ('decisum', 'O'),
#   ("''", 'O'),
#   ('e', 'O'),
#   ('a', 'O'),
#   ('decretação', 'O'),
#   ('de', 'O'),
#   ('nulidade', 'O'),
#   ('de', 'O'),
#   ('todos', 'O'),
#   ('os', 'O'),
#   ('atos', 'O'),
#   ('decisórios', 'O'),
#   (',', 'O'),
#   ('desde', 'O'),
#   ('o', 'O'),
#   ('primeiro', 'O'),
#   ('momento', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('o', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('deveria', 'O'),
#   ('ter', 'O'),
#   ('se', 'O'),
#   ('pronunciado', 'O'),
#   ('nos', 'O'),
#   ('autos', 'O'),
#   ('.', 'O')],
#  [('(', 'O'),
#   ('TJMG', 'B-ORGANIZACAO'),
#   ('-', 'O'),
#   ('Apelação', 'B-JURISPRUDENCIA'),
#   ('Cível', 'I-JURISPRUDENCIA'),
#   ('1.0024.13.330164-8/001', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Relator', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   (':', 'O'),
#   ('Des', 'O'),
#   ('.', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   ('Aparecida', 'B-PESSOA'),
#   ('Grossi', 'I-PESSOA'),
#   (',', 'O'),
#   ('16ª', 'B-ORGANIZACAO'),
#   ('CÂMARA', 'I-ORGANIZACAO'),
#   ('CÍVEL', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgamento', 'O'),
#   ('em', 'O'),
#   ('06/10/0017', 'B-TEMPO'),
#   (',', 'O'),
#   ('publicação', 'O'),
#   ('da', 'O'),
#   ('súmula', 'O'),
#   ('em', 'O'),
#   ('11/10/2017', 'B-TEMPO'),
#   (')', 'O'),
#   ('EMENTA', 'O'),
#   (':', 'O'),
#   ('DIREITO', 'O'),
#   ('PROCESSUAL', 'O'),
#   ('CIVIL', 'O'),
#   ('.', 'O')],
#  [('APELAÇÃO', 'O'), ('CÍVEL', 'O'), ('.', 'O')],
#  [('AÇÃO', 'O'),
#   ('ORDINÁRIA', 'O'),
#   ('DE', 'O'),
#   ('DECLARAÇÃO', 'O'),
#   ('DE', 'O'),
#   ('NULIDADE', 'O'),
#   ('OU', 'O'),
#   ('ANULABILIDADE', 'O'),
#   ('DE', 'O'),
#   ('NEGÓCIO', 'O'),
#   ('JURÍDICO', 'O'),
#   ('.', 'O')],
#  [('PRESENÇA', 'O'),
#   ('DE', 'O'),
#   ('INTERESSE', 'O'),
#   ('DE', 'O'),
#   ('INCAPAZ', 'O'),
#   ('.', 'O')],
#  [('NECESSIDADE', 'O'),
#   ('DE', 'O'),
#   ('INTERVENÇÃO', 'O'),
#   ('DO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('INOBSERVÂNCIA', 'O'), ('.', 'O')],
#  [('NULIDADE', 'O'), ('.', 'O')],
#  [('OCORRÊNCIA', 'O'), ('.', 'O')],
#  [('SENTENÇA', 'O'), ('DESCONSTITUÍDA', 'O'), ('.', 'O')],
#  [('1', 'O'), ('.', 'O')],
#  [('A', 'O'),
#   ('falta', 'O'),
#   ('de', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('nas', 'O'),
#   ('ações', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('deva', 'O'),
#   ('figurar', 'O'),
#   ('como', 'O'),
#   ('fiscal', 'O'),
#   ('da', 'O'),
#   ('lei', 'O'),
#   ('e', 'O'),
#   ('da', 'O'),
#   ('Constituição', 'B-LEGISLACAO'),
#   ('(', 'O'),
#   ("'custus", 'O'),
#   ('legis', 'O'),
#   ('et', 'O'),
#   ('constituitionis', 'O'),
#   ("'", 'O'),
#   (')', 'O'),
#   ('enseja', 'O'),
#   ('de', 'O'),
#   ('forma', 'O'),
#   ('inexorável', 'O'),
#   ('a', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('processo', 'O'),
#   (',', 'O'),
#   ('segundo', 'O'),
#   ('prescreve', 'O'),
#   ('o', 'O'),
#   ('artigo', 'B-LEGISLACAO'),
#   ('279', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('§', 'I-LEGISLACAO'),
#   ('1º', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('CPC', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('caso', 'O'),
#   ('arguido', 'O'),
#   ('e', 'O'),
#   ('constatado', 'O'),
#   ('o', 'O'),
#   ('prejuízo', 'O'),
#   ('do', 'O'),
#   ('incapaz', 'O'),
#   ('que', 'O'),
#   ('justifica', 'O'),
#   ('sua', 'O'),
#   ('intervenção', 'O'),
#   ('(', 'O'),
#   ('§', 'O'),
#   ('2º', 'O'),
#   (')', 'O'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('(', 'O'),
#   ('TJMG', 'B-ORGANIZACAO'),
#   ('-', 'O'),
#   ('Apelação', 'B-JURISPRUDENCIA'),
#   ('Cível', 'I-JURISPRUDENCIA'),
#   ('1.0549.15.003028-2/003', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Relator', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   (':', 'O'),
#   ('Des', 'O'),
#   ('.', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   ('Otávio', 'B-PESSOA'),
#   ('Portes', 'I-PESSOA'),
#   (',', 'O'),
#   ('16ª', 'B-ORGANIZACAO'),
#   ('CÂMARA', 'I-ORGANIZACAO'),
#   ('CÍVEL', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgamento', 'O'),
#   ('em', 'O'),
#   ('28/09/2017', 'B-TEMPO'),
#   (',', 'O'),
#   ('publicação', 'O'),
#   ('da', 'O'),
#   ('súmula', 'O'),
#   ('em', 'O'),
#   ('06/10/2017', 'B-TEMPO'),
#   (')', 'O'),
#   ('Assim', 'O'),
#   ('sendo', 'O'),
#   (',', 'O'),
#   ('entendo', 'O'),
#   ('que', 'O'),
#   ('deve', 'O'),
#   ('ser', 'O'),
#   ('acolhida', 'O'),
#   ('a', 'O'),
#   ('preliminar', 'O'),
#   ('de', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('feito', 'O'),
#   ('arguida', 'O'),
#   ('pelo', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('na', 'O'),
#   ('instância', 'O'),
#   ('recursal', 'O'),
#   (',', 'O'),
#   ('sobremaneira', 'O'),
#   (',', 'O'),
#   ('quando', 'O'),
#   ('há', 'O'),
#   ('prejuízo', 'O'),
#   ('para', 'O'),
#   ('o', 'O'),
#   ('incapaz', 'O'),
#   ('.', 'O')],
#  [('Isso', 'O'),
#   ('posto', 'O'),
#   (',', 'O'),
#   ('ACOLHO', 'O'),
#   ('A', 'O'),
#   ('PRELIMINAR', 'O'),
#   ('DE', 'O'),
#   ('NULIDADE', 'O'),
#   ('DO', 'O'),
#   ('FEITO', 'O'),
#   ('ARGUIDA', 'O'),
#   ('PELO', 'O'),
#   ('MINISTÉRIO', 'B-ORGANIZACAO'),
#   ('PÚBLICO', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('cassando', 'O'),
#   ('a', 'O'),
#   ('sentença', 'O'),
#   ('apelada', 'O'),
#   ('e', 'O'),
#   ('determinando', 'O'),
#   ('o', 'O'),
#   ('retorno', 'O'),
#   ('dos', 'O'),
#   ('autos', 'O'),
#   ('ao', 'O'),
#   ('primeiro', 'O'),
#   ('grau', 'O'),
#   (',', 'O'),
#   ('para', 'O'),
#   ('permitir', 'O'),
#   ('a', 'O'),
#   ('efetiva', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Representante', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('na', 'O'),
#   ('instância', 'O'),
#   ('a', 'O'),
#   ('quo', 'O'),
#   ('.', 'O')],
#  [('Custas', 'O'),
#   ('ao', 'O'),
#   ('final', 'O'),
#   ('pelo', 'O'),
#   ('vencido', 'O'),
#   ('.', 'O')],
#  [('É', 'O'), ('como', 'O'), ('voto', 'O'), ('.', 'O')],
#  [('DES', 'O'),
#   ('.', 'O'),
#   ('VICENTE', 'B-PESSOA'),
#   ('DE', 'I-PESSOA'),
#   ('OLIVEIRA', 'I-PESSOA'),
#   ('SILVA', 'I-PESSOA'),
#   ('-', 'O'),
#   ('De', 'O'),
#   ('acordo', 'O'),
#   ('com', 'O'),
#   ('o', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   ('Relator', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('DES', 'O'),
#   ('.', 'O'),
#   ('MANOEL', 'B-PESSOA'),
#   ('DOS', 'I-PESSOA'),
#   ('REIS', 'I-PESSOA'),
#   ('MORAIS', 'I-PESSOA'),
#   ('Com', 'O'),
#   ('a', 'O'),
#   ('devida', 'O'),
#   ('vênia', 'O'),
#   ('da', 'O'),
#   ('e.', 'O'),
#   ('Desª', 'O'),
#   ('.', 'O')],
#  [('Relatora', 'O'),
#   (',', 'O'),
#   ('entende-se', 'O'),
#   ('que', 'O'),
#   ('no', 'O'),
#   ('caso', 'O'),
#   ('não', 'O'),
#   ('há', 'O'),
#   ('prejuízo', 'O'),
#   ('à', 'O'),
#   ('parte', 'O'),
#   ('Autora', 'O'),
#   ('a', 'O'),
#   ('ensejar', 'O'),
#   ('a', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('processo', 'O'),
#   ('por', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('participação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('.', 'O')],
#  [('A', 'O'),
#   ('Apelante', 'O'),
#   ('está', 'O'),
#   ('devidamente', 'O'),
#   ('assistida', 'O'),
#   ('por', 'O'),
#   ('sua', 'O'),
#   ('curadora', 'O'),
#   ('e', 'O'),
#   ('representada', 'O'),
#   ('por', 'O'),
#   ('advogado', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('qual', 'O'),
#   ('zelou', 'O'),
#   ('pela', 'O'),
#   ('defesa', 'O'),
#   ('de', 'O'),
#   ('seus', 'O'),
#   ('interesses', 'O'),
#   ('.', 'O')],
#  [('A', 'O'),
#   ('nulidade', 'O'),
#   ('por', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('participação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   ('somente', 'O'),
#   ('deve', 'O'),
#   ('ser', 'O'),
#   ('declarada', 'O'),
#   ('nas', 'O'),
#   ('hipóteses', 'O'),
#   ('de', 'O'),
#   ('constatação', 'O'),
#   ('de', 'O'),
#   ('vício', 'O'),
#   ('que', 'O'),
#   ('acarrete', 'O'),
#   ('prejuízo', 'O'),
#   ('à', 'O'),
#   ('parte', 'O'),
#   ('que', 'O'),
#   ('contaria', 'O'),
#   ('com', 'O'),
#   ('a', 'O'),
#   ('garantia', 'O'),
#   ('de', 'O'),
#   ('participação', 'O'),
#   ('do', 'O'),
#   ('parquet', 'B-PESSOA'),
#   (',', 'O'),
#   ('ou', 'O'),
#   ('seja', 'O'),
#   (',', 'O'),
#   ('quando', 'O'),
#   ('há', 'O'),
#   ('patente', 'O'),
#   ('desequilíbrio', 'O'),
#   ('na', 'O'),
#   ('relação', 'O'),
#   ('jurídica', 'O'),
#   ('que', 'O'),
#   ('poderia', 'O'),
#   ('ter', 'O'),
#   ('sido', 'O'),
#   ('suprida', 'O'),
#   ('com', 'O'),
#   ('a', 'O'),
#   ('participação', 'O'),
#   ('ministerial', 'O'),
#   ('.', 'O')],
#  [('Sobre', 'O'),
#   ('o', 'O'),
#   ('tema', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('orientação', 'O'),
#   ('do', 'O'),
#   ('STJ', 'B-ORGANIZACAO'),
#   (':', 'O'),
#   ("''", 'O'),
#   ('RECURSO', 'O'),
#   ('ESPECIAL', 'O'),
#   ('.', 'O')],
#  [('PROCESSO', 'O'), ('CIVIL', 'O'), ('.', 'O')],
#  [('AÇÃO', 'O'),
#   ('DE', 'O'),
#   ('RESCISÃO', 'O'),
#   ('CONTRATUAL', 'O'),
#   ('.', 'O')],
#  [('CITAÇÃO', 'O'),
#   ('EM', 'O'),
#   ('NOME', 'O'),
#   ('DE', 'O'),
#   ('INCAPAZ', 'O'),
#   ('.', 'O')],
#  [('INCAPACIDADE', 'O'),
#   ('DECLARADA', 'O'),
#   ('POSTERIORMENTE', 'O'),
#   ('.', 'O')],
#  [('NULIDADE', 'O'), ('NÃO', 'O'), ('RECONHECIDA', 'O'), ('.', 'O')],
#  [('INTERVENÇÃO', 'O'), ('DO', 'O'), ('MP', 'B-ORGANIZACAO'), ('.', 'O')],
#  [('NULIDADE', 'O'), ('.', 'O')],
#  [('NECESSIDADE', 'O'),
#   ('DE', 'O'),
#   ('DEMONSTRAÇÃO', 'O'),
#   ('DO', 'O'),
#   ('PREJUÍZO', 'O'),
#   ('.', 'O')],
#  [('ESTATUTO', 'O'),
#   ('DA', 'O'),
#   ('PESSOA', 'O'),
#   ('COM', 'O'),
#   ('DEFICIÊNCIA', 'O'),
#   ('.', 'O')],
#  [('LEI', 'B-LEGISLACAO'),
#   ('N', 'I-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('13.146/2015', 'I-LEGISLACAO'),
#   ('.', 'O')],
#  [('DISSOCIAÇÃO', 'O'),
#   ('ENTRE', 'O'),
#   ('TRANSTORNO', 'O'),
#   ('MENTAL', 'O'),
#   ('E', 'O'),
#   ('INCAPACIDADE', 'O'),
#   ('.', 'O')],
#  [('(', 'O'), ('...', 'O'), (')', 'O'), ('.', 'O')],
#  [('4', 'O'), ('.', 'O')],
#  [('A', 'O'),
#   ('intervenção', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('nos', 'O'),
#   ('processos', 'O'),
#   ('que', 'O'),
#   ('envolvam', 'O'),
#   ('interesse', 'O'),
#   ('de', 'O'),
#   ('incapaz', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('motiva', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('ao', 'O'),
#   ('mesmo', 'O'),
#   ('tempo', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('justifica', 'O'),
#   ('na', 'O'),
#   ('possibilidade', 'O'),
#   ('de', 'O'),
#   ('desequilíbrio', 'O'),
#   ('da', 'O'),
#   ('relação', 'O'),
#   ('jurídica', 'O'),
#   ('e', 'O'),
#   ('no', 'O'),
#   ('eventual', 'O'),
#   ('comprometimento', 'O'),
#   ('do', 'O'),
#   ('contraditório', 'O'),
#   ('em', 'O'),
#   ('função', 'O'),
#   ('da', 'O'),
#   ('existência', 'O'),
#   ('da', 'O'),
#   ('parte', 'O'),
#   ('vulnerável', 'O'),
#   ('.', 'O')],
#  [('5', 'O'), ('.', 'O')],
#  [('A', 'O'),
#   ('ausência', 'O'),
#   ('da', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('quando', 'O'),
#   ('necessária', 'O'),
#   ('sua', 'O'),
#   ('intervenção', 'O'),
#   (',', 'O'),
#   ('por', 'O'),
#   ('si', 'O'),
#   ('só', 'O'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('enseja', 'O'),
#   ('a', 'O'),
#   ('decretação', 'O'),
#   ('de', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('julgado', 'O'),
#   (',', 'O'),
#   ('sendo', 'O'),
#   ('necessária', 'O'),
#   ('a', 'O'),
#   ('demonstração', 'O'),
#   ('do', 'O'),
#   ('efetivo', 'O'),
#   ('prejuízo', 'O'),
#   ('para', 'O'),
#   ('as', 'O'),
#   ('partes', 'O'),
#   ('ou', 'O'),
#   ('para', 'O'),
#   ('a', 'O'),
#   ('apuração', 'O'),
#   ('da', 'O'),
#   ('verdade', 'O'),
#   ('substancial', 'O'),
#   ('da', 'O'),
#   ('controvérsia', 'O'),
#   ('jurídica', 'O'),
#   (',', 'O'),
#   ('à', 'O'),
#   ('luz', 'O'),
#   ('do', 'O'),
#   ('princípio', 'O'),
#   ('pas', 'O'),
#   ('de', 'O'),
#   ('nullité', 'O'),
#   ('sans', 'O'),
#   ('grief', 'O'),
#   ('.', 'O')],
#  [('(', 'O'), ('...', 'O'), (')', 'O'), ('.', 'O')],
#  [('10', 'O'),
#   ('.', 'O'),
#   ('Recurso', 'O'),
#   ('especial', 'O'),
#   ('a', 'O'),
#   ('que', 'O'),
#   ('se', 'O'),
#   ('nega', 'O'),
#   ('provimento', 'O'),
#   ('.', 'O')],
#  [('(', 'O'), ('STJ', 'B-ORGANIZACAO'), ('.', 'O')],
#  [('REsp', 'B-JURISPRUDENCIA'),
#   ('n', 'I-JURISPRUDENCIA'),
#   ('.', 'I-JURISPRUDENCIA'),
#   ('1694984/MS', 'I-JURISPRUDENCIA'),
#   (',', 'O'),
#   ('Rel', 'O'),
#   ('.', 'O'),
#   ('Ministro', 'O'),
#   ('LUIS', 'B-PESSOA'),
#   ('FELIPE', 'I-PESSOA'),
#   ('SALOMÃO', 'I-PESSOA'),
#   (',', 'O'),
#   ('QUARTA', 'B-ORGANIZACAO'),
#   ('TURMA', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('julgado', 'O'),
#   ('em', 'O'),
#   ('14/11/2017', 'B-TEMPO'),
#   (',', 'O'),
#   ('DJe', 'O'),
#   ('01/02/2018', 'B-TEMPO'),
#   (')', 'O'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('``', 'O'), ('PROCESSUAL', 'O'), ('CIVIL', 'O'), ('.', 'O')],
#  [('AGRAVO', 'O'),
#   ('REGIMENTAL', 'O'),
#   ('NO', 'O'),
#   ('RECURSO', 'O'),
#   ('ESPECIAL', 'O'),
#   ('.', 'O')],
#  [('AÇÃO', 'O'), ('POPULAR', 'O'), ('.', 'O')],
#  [('INTIMAÇÃO', 'O'), ('.', 'O')],
#  [('OBRIGATORIEDADE', 'O'), ('.', 'O')],
#  [('NULIDADE', 'O'), ('.', 'O')],
#  [('INOCORRÊNCIA', 'O'), ('.', 'O')],
#  [('DECISÃO', 'O'),
#   ('EM', 'O'),
#   ('CONFORMIDADE', 'O'),
#   ('COM', 'O'),
#   ('A', 'O'),
#   ('ORIENTAÇÃO', 'O'),
#   ('JURISPRUDENCIAL', 'O'),
#   ('DESTA', 'O'),
#   ('CORTE', 'O'),
#   ('.', 'O')],
#  [('1', 'O'), ('.', 'O')],
#  [('A', 'O'),
#   ('decisão', 'O'),
#   ('impugnada', 'O'),
#   ('merece', 'O'),
#   ('confirmação', 'O'),
#   (',', 'O'),
#   ('na', 'O'),
#   ('medida', 'O'),
#   ('em', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('jurisprudência', 'O'),
#   ('deste', 'O'),
#   ('Superior', 'B-ORGANIZACAO'),
#   ('Tribunal', 'I-ORGANIZACAO'),
#   ('de', 'I-ORGANIZACAO'),
#   ('Justiça', 'I-ORGANIZACAO'),
#   ('ja', 'O'),
#   ('sedimentou', 'O'),
#   ('no', 'O'),
#   ('sentido', 'O'),
#   ('de', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('ausência', 'O'),
#   ('de', 'O'),
#   ('intimação', 'O'),
#   ('do', 'O'),
#   ('Ministério', 'B-ORGANIZACAO'),
#   ('Público', 'I-ORGANIZACAO'),
#   (',', 'O'),
#   ('por', 'O'),
#   ('si', 'O'),
#   ('só', 'O'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('gera', 'O'),
#   ('nulidade', 'O'),
#   ('do', 'O'),
#   ('julgado', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('não', 'O'),
#   ('ser', 'O'),
#   ('que', 'O'),
#   ('se', 'O'),
#   ('constate', 'O'),
#   ('``', 'O'),
#   ('efetivo', 'O'),
#   ('prejuízo', 'O'),
#   ('para', 'O'),
#   ('as', 'O'),
#   ('partes', 'O'),
#   ('ou', 'O'),
#   ('para', 'O'),
#   ('apuração', 'O'),
#   ('ou', 'O'),
#   ('para', 'O'),
#   ('apuração', 'O'),
# ...
#   ('Ressalte-se', 'O'),
#   (',', 'O'),
#   ('ainda', 'O'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('cabe', 'O'),
#   ('ao', 'O'),
#   ('Distrito', 'B-ORGANIZACAO'),
#   ('Federal', 'I-ORGANIZACAO'),
#   ('respeitar', 'O'),
#   ('as', 'O'),
#   ('definições', 'O'),
#   ('e', 'O'),
#   ('os', 'O'),
#   ('critérios', 'O'),
#   ('insertos', 'O'),
#   ('no', 'O'),
#   ('Decreto', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('10.829/1987', 'I-LEGISLACAO'),
#   ('e', 'O'),
#   ('na', 'O'),
#   ('Portaria', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('314/1992', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('do', 'O'),
#   ('Instituto', 'B-ORGANIZACAO'),
#   ('Brasileiro', 'I-ORGANIZACAO'),
#   ('do', 'I-ORGANIZACAO'),
#   ('Patrimônio', 'I-ORGANIZACAO'),
#   ('Histórico', 'I-ORGANIZACAO'),
#   ('e', 'I-ORGANIZACAO'),
#   ('Artístico', 'I-ORGANIZACAO'),
#   ('Nacional', 'I-ORGANIZACAO'),
#   ('IPHAN', 'B-ORGANIZACAO'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('de', 'O'),
#   ('outro', 'O'),
#   ('lado', 'O'),
#   ('é', 'O'),
#   ('competência', 'O'),
#   ('privativa', 'O'),
#   ('do', 'O'),
#   ('Governador', 'O'),
#   ('a', 'O'),
#   ('iniciativa', 'O'),
#   ('do', 'O'),
#   ('processo', 'O'),
#   ('legislativo', 'O'),
#   ('a', 'O'),
#   ('respeito', 'O'),
#   ('do', 'O'),
#   ('uso', 'O'),
#   ('e', 'O'),
#   ('ocupação', 'O'),
#   ('do', 'O'),
#   ('solo', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   (',', 'O'),
#   ('sendo', 'O'),
#   ('responsabilidade', 'O'),
#   ('da', 'O'),
#   ('Câmara', 'B-ORGANIZACAO'),
#   ('Legislativa', 'I-ORGANIZACAO'),
#   ('apenas', 'O'),
#   ('a', 'O'),
#   ('votação', 'O'),
#   ('de', 'O'),
#   ('tal', 'O'),
#   ('projeto', 'O'),
#   ('.', 'O')],
#  [('Vejamos', 'O'),
#   ('a', 'O'),
#   ('redação', 'O'),
#   ('do', 'O'),
#   ('artigo', 'B-LEGISLACAO'),
#   ('3º', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('item', 'I-LEGISLACAO'),
#   ('XI', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('da', 'I-LEGISLACAO'),
#   ('Lei', 'I-LEGISLACAO'),
#   ('Orgânica', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('Distrito', 'I-LEGISLACAO'),
#   ('Federal', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('verbis', 'O'),
#   (':', 'O'),
#   ('“', 'O'),
#   ('Art', 'O'),
#   ('.', 'O'),
#   ('3º', 'O'),
#   ('.', 'O')],
#  [('São', 'O'),
#   ('objetivos', 'O'),
#   ('prioritários', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-ORGANIZACAO'),
#   ('Federal', 'I-ORGANIZACAO'),
#   (':', 'O'),
#   ('(', 'O'),
#   ('...', 'O'),
#   (')', 'O'),
#   ('XI', 'O'),
#   ('zelar', 'O'),
#   ('pelo', 'O'),
#   ('conjunto', 'O'),
#   ('urbanístico', 'O'),
#   ('de', 'O'),
#   ('Brasília', 'B-LOCAL'),
#   (',', 'O'),
#   ('tombado', 'O'),
#   ('sob', 'O'),
#   ('a', 'O'),
#   ('inscrição', 'O'),
#   ('nº', 'O'),
#   ('532', 'O'),
#   (',', 'O'),
#   ('do', 'O'),
#   ('Livro', 'O'),
#   ('do', 'O'),
#   ('Tombo', 'O'),
#   ('Histórico', 'O'),
#   (',', 'O'),
#   ('respeitadas', 'O'),
#   ('as', 'O'),
#   ('definições', 'O'),
#   ('e', 'O'),
#   ('critérios', 'O'),
#   ('constantes', 'O'),
#   ('do', 'O'),
#   ('Decreto', 'B-LEGISLACAO'),
#   ('nº', 'I-LEGISLACAO'),
#   ('10.829', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('2', 'B-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('outubro', 'I-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('1987', 'I-TEMPO'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('da', 'O'),
#   ('Portaria', 'B-LEGISLACAO'),
#   ('n', 'I-LEGISLACAO'),
#   ('314', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('08', 'B-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('outubro', 'I-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('1992', 'I-TEMPO'),
#   (',', 'O'),
#   ('do', 'O'),
#   ('então', 'O'),
#   ('Instituto', 'B-ORGANIZACAO'),
#   ('Brasileiro', 'I-ORGANIZACAO'),
#   ('do', 'I-ORGANIZACAO'),
#   ('Patrimônio', 'I-ORGANIZACAO'),
#   ('Cultural', 'I-ORGANIZACAO'),
#   ('IBPC', 'B-ORGANIZACAO'),
#   (',', 'O'),
#   ('hoje', 'O'),
#   ('Instituto', 'B-ORGANIZACAO'),
#   ('do', 'I-ORGANIZACAO'),
#   ('patrimônio', 'I-ORGANIZACAO'),
#   ('Histórico', 'I-ORGANIZACAO'),
#   ('e', 'I-ORGANIZACAO'),
#   ('Artístico', 'I-ORGANIZACAO'),
#   ('Nacional', 'I-ORGANIZACAO'),
#   ('IPHAN.', 'B-ORGANIZACAO'),
#   ('”', 'O'),
#   ('Tanto', 'O'),
#   ('o', 'O'),
#   ('referido', 'O'),
#   ('Decreto', 'O'),
#   (',', 'O'),
#   ('precisamente', 'O'),
#   ('no', 'O'),
#   ('seu', 'O'),
#   ('artigo', 'O'),
#   ('14', 'O'),
#   (',', 'O'),
#   ('como', 'O'),
#   ('na', 'O'),
#   ('Portaria', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('314/1992', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('conferem', 'O'),
#   ('ao', 'O'),
#   ('Governador', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('competência', 'O'),
#   ('privativa', 'O'),
#   ('para', 'O'),
#   ('iniciar', 'O'),
#   ('o', 'O'),
#   ('processo', 'O'),
#   ('legislativo', 'O'),
#   (',', 'O'),
#   ('quando', 'O'),
#   ('se', 'O'),
#   ('tratar', 'O'),
#   ('o', 'O'),
#   ('tema', 'O'),
#   ('de', 'O'),
#   ('uso', 'O'),
#   ('e', 'O'),
#   ('ocupação', 'O'),
#   ('do', 'O'),
#   ('solo', 'O'),
#   ('em', 'O'),
#   ('todo', 'O'),
#   ('o', 'O'),
#   ('território', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('.', 'O')],
#  [('Senão', 'O'),
#   ('vejamos', 'O'),
#   (':', 'O'),
#   ('“', 'O'),
#   ('Art', 'O'),
#   ('.', 'O'),
#   ('14', 'O'),
#   ('O', 'O'),
#   ('Governador', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('proporá', 'O'),
#   ('a', 'O'),
#   ('edição', 'O'),
#   ('de', 'O'),
#   ('leis', 'O'),
#   ('que', 'O'),
#   ('venham', 'O'),
#   ('a', 'O'),
#   ('dispor', 'O'),
#   ('sobre', 'O'),
#   ('o', 'O'),
#   ('uso', 'O'),
#   ('e', 'O'),
#   ('ocupação', 'O'),
#   ('do', 'O'),
#   ('solo', 'O'),
#   ('em', 'O'),
#   ('todo', 'O'),
#   ('o', 'O'),
#   ('território', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal.', 'I-LOCAL'),
#   ('”', 'O'),
#   ('Assim', 'O'),
#   (',', 'O'),
#   ('conjugando', 'O'),
#   ('o', 'O'),
#   ('art', 'O'),
#   ('.', 'O'),
#   ('14', 'O'),
#   (',', 'O'),
#   ('do', 'O'),
#   ('Decreto', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('10.829/87', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('passou', 'O'),
#   ('a', 'O'),
#   ('integrar', 'O'),
#   ('a', 'O'),
#   ('Lei', 'B-LEGISLACAO'),
#   ('Orgânica', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('Distrito', 'I-LEGISLACAO'),
#   ('Federal', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('por', 'O'),
#   ('intermédio', 'O'),
#   ('da', 'O'),
#   ('Emenda', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('12/96', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('com', 'O'),
#   ('o', 'O'),
#   ('artigo', 'B-LEGISLACAO'),
#   ('100', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('item', 'I-LEGISLACAO'),
#   ('VI', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('da', 'I-LEGISLACAO'),
#   ('LODF', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('extrai-se', 'O'),
#   ('ser', 'O'),
#   ('competência', 'O'),
#   ('privativa', 'O'),
#   ('do', 'O'),
#   ('Governador', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('legislar', 'O'),
#   ('sobre', 'O'),
#   ('matéria', 'O'),
#   ('concernente', 'O'),
#   ('ao', 'O'),
#   ('uso', 'O'),
#   ('e', 'O'),
#   ('ocupação', 'O'),
#   ('do', 'O'),
#   ('solo', 'O'),
#   ('no', 'O'),
#   ('território', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('.', 'O')],
#  [('Em', 'O'),
#   ('que', 'O'),
#   ('pese', 'O'),
#   ('o', 'O'),
#   ('Decreto', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('10.829/87', 'I-LEGISLACAO'),
#   ('e', 'O'),
#   ('a', 'O'),
#   ('Portaria', 'B-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('314/92', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('do', 'O'),
#   ('IPHAN', 'B-ORGANIZACAO'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('tenham', 'O'),
#   ('status', 'O'),
#   ('de', 'O'),
#   ('norma', 'O'),
#   ('constitucional', 'O'),
#   (',', 'O'),
#   ('e', 'O'),
#   (',', 'O'),
#   ('portanto', 'O'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('sirvam', 'O'),
#   ('de', 'O'),
#   ('parâmetro', 'O'),
#   ('para', 'O'),
#   ('o', 'O'),
#   ('exame', 'O'),
#   ('de', 'O'),
#   ('constitucionalidade', 'O'),
#   ('da', 'O'),
#   ('norma', 'O'),
#   ('impugnada', 'O'),
#   (',', 'O'),
#   ('o', 'O'),
#   ('art', 'B-LEGISLACAO'),
#   ('.', 'I-LEGISLACAO'),
#   ('3º', 'I-LEGISLACAO'),
#   (',', 'I-LEGISLACAO'),
#   ('da', 'I-LEGISLACAO'),
#   ('LODF', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('impõe', 'O'),
#   ('a', 'O'),
#   ('observância', 'O'),
#   ('e', 'O'),
#   ('obediência', 'O'),
#   ('de', 'O'),
#   ('tais', 'O'),
#   ('normas', 'O'),
#   (',', 'O'),
#   ('inclusive', 'O'),
#   ('no', 'O'),
#   ('que', 'O'),
#   ('tange', 'O'),
#   ('ao', 'O'),
#   ('citado', 'O'),
#   ('art', 'O'),
#   ('.', 'O'),
#   ('14', 'O'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('trata', 'O'),
#   ('da', 'O'),
#   ('iniciativa', 'O'),
#   ('de', 'O'),
#   ('leis', 'O'),
#   ('que', 'O'),
#   ('disponham', 'O'),
#   ('sobre', 'O'),
#   ('o', 'O'),
#   ('uso', 'O'),
#   ('e', 'O'),
#   ('ocupação', 'O'),
#   ('do', 'O'),
#   ('solo', 'O'),
#   ('em', 'O'),
#   ('todo', 'O'),
#   ('o', 'O'),
#   ('território', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('.', 'O')],
#  [('Ante', 'O'),
#   ('o', 'O'),
#   ('exposto', 'O'),
#   (',', 'O'),
#   ('JULGO', 'O'),
#   ('PROCEDENTE', 'O'),
#   ('o', 'O'),
#   ('pedido', 'O'),
#   ('deduzido', 'O'),
#   ('na', 'O'),
#   ('presente', 'O'),
#   ('ação', 'O'),
#   ('direta', 'O'),
#   ('para', 'O'),
#   ('declarar', 'O'),
#   (',', 'O'),
#   ('com', 'O'),
#   ('efeito', 'O'),
#   ('ex', 'O'),
#   ('tunc', 'O'),
#   ('e', 'O'),
#   ('eficácia', 'O'),
#   ('erga', 'O'),
#   ('omnes', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('inconstitucionalidade', 'O'),
#   ('formal', 'O'),
#   ('das', 'O'),
#   ('Leis', 'B-LEGISLACAO'),
#   ('distritais', 'I-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('747', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('23', 'B-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('agosto', 'I-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('1994', 'I-TEMPO'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('2.018', 'B-LEGISLACAO'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('28', 'B-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('julho', 'I-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('1998', 'I-TEMPO'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('da', 'O'),
#   ('Lei', 'B-LEGISLACAO'),
#   ('Complementar', 'I-LEGISLACAO'),
#   ('distrital', 'I-LEGISLACAO'),
#   ('n.º', 'I-LEGISLACAO'),
#   ('380', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('4', 'B-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('abril', 'I-TEMPO'),
#   ('de', 'I-TEMPO'),
#   ('2001', 'I-TEMPO'),
#   ('.', 'O')],
#  [('É', 'O'), ('o', 'O'), ('voto', 'O'), ('.', 'O')],
#  [('O', 'O'),
#   ('Senhor', 'O'),
#   ('Desembargador', 'O'),
#   ('JOÃO', 'B-PESSOA'),
#   ('MARIOSI', 'I-PESSOA'),
#   ('Vogal', 'O'),
#   ('Senhor', 'O'),
#   ('Presidente', 'O'),
#   (',', 'O'),
#   ('ouvi', 'O'),
#   ('a', 'O'),
#   ('parte', 'O'),
#   ('inicial', 'O'),
#   ('da', 'O'),
#   ('votação', 'O'),
#   (',', 'O'),
#   ('que', 'O'),
#   ('trata', 'O'),
#   ('da', 'O'),
#   ('competência', 'O'),
#   ('constitucional', 'O'),
#   (',', 'O'),
#   ('Constituição', 'B-LEGISLACAO'),
#   ('de', 'I-LEGISLACAO'),
#   ('1988', 'I-LEGISLACAO'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('respeito', 'O'),
#   ('da', 'O'),
#   ('ação', 'O'),
#   ('direta', 'O'),
#   ('de', 'O'),
#   ('inconstitucionalidade', 'O'),
#   (',', 'O'),
#   ('mas', 'O'),
#   (',', 'O'),
#   ('na', 'O'),
#   ('verdade', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('minha', 'O'),
#   ('decisão', 'O'),
#   ('é', 'O'),
#   ('sempre', 'O'),
#   ('no', 'O'),
#   ('sentido', 'O'),
#   ('contrário', 'O'),
#   (',', 'O'),
#   ('porque', 'O'),
#   (',', 'O'),
#   ('quando', 'O'),
#   ('o', 'O'),
#   ('legislador', 'O'),
#   ('originário', 'O'),
#   ('quis', 'O'),
#   ('colocar', 'O'),
#   ('o', 'O'),
#   ('Distrito', 'B-ORGANIZACAO'),
#   ('Federal', 'I-ORGANIZACAO'),
#   ('em', 'O'),
#   ('nível', 'O'),
#   ('de', 'O'),
#   ('igualdade', 'O'),
#   ('com', 'O'),
#   ('os', 'O'),
#   ('estados', 'O'),
#   (',', 'O'),
#   ('ele', 'O'),
#   ('sempre', 'O'),
#   ('o', 'O'),
#   ('disse', 'O'),
#   (',', 'O'),
#   ('com', 'O'),
#   ('todas', 'O'),
#   ('as', 'O'),
#   ('letras', 'O'),
#   ('.', 'O')],
#  [('No', 'O'),
#   ('entanto', 'O'),
#   (',', 'O'),
#   ('neste', 'O'),
#   ('caso', 'O'),
#   ('específico', 'O'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('o', 'O'),
#   ('disse', 'O'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('os', 'O'),
#   ('votos', 'O'),
#   ('trazidos', 'O'),
#   ('do', 'O'),
#   ('Ministro', 'O'),
#   ('Celso', 'B-PESSOA'),
#   ('de', 'I-PESSOA'),
#   ('Mello', 'I-PESSOA'),
#   ('são', 'O'),
#   ('en', 'O'),
#   ('passant', 'O'),
#   ('e', 'O'),
#   ('circunstanciais', 'O'),
#   ('.', 'O')],
#  [('S.', 'O'),
#   ('Ex.a', 'O'),
#   ('parte', 'O'),
#   ('de', 'O'),
#   ('uma', 'O'),
#   ('premissa', 'O'),
#   (',', 'O'),
#   ('sem', 'O'),
#   ('aprofundar', 'O'),
#   ('a', 'O'),
#   ('questão', 'O'),
#   (',', 'O'),
#   ('afirmando', 'O'),
#   ('a', 'O'),
#   ('competência', 'O'),
#   ('deste', 'O'),
#   ('Tribunal', 'O'),
#   ('para', 'O'),
#   ('julgar', 'O'),
#   ('esses', 'O'),
#   ('tipos', 'O'),
#   ('de', 'O'),
#   ('ação', 'O'),
#   ('direta', 'O'),
#   ('de', 'O'),
#   ('inconstitucionalidade', 'O'),
#   ('.', 'O')],
#  [('É', 'O'),
#   ('bem', 'O'),
#   ('verdade', 'O'),
#   ('que', 'O'),
#   ('vivemos', 'O'),
#   ('uma', 'O'),
#   ('época', 'O'),
#   ('constitucionalista', 'O'),
#   ('de', 'O'),
#   ('revisão', 'O'),
#   (',', 'O'),
#   ('pelo', 'O'),
#   ('Judiciário', 'O'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('um', 'O'),
#   ('sistema', 'O'),
#   ('copiado', 'O'),
#   ('do', 'O'),
#   ('alemão', 'O'),
#   ('e', 'O'),
#   ('infundido', 'O'),
#   ('em', 'O'),
#   ('terras', 'O'),
#   ('brasileiras', 'O'),
#   (',', 'O'),
#   ('mas', 'O'),
#   (',', 'O'),
#   ('na', 'O'),
#   ('verdade', 'O'),
#   (',', 'O'),
#   ('se', 'O'),
#   ('a', 'O'),
#   ('coisa', 'O'),
#   ('permanece', 'O'),
#   (',', 'O'),
#   ('evidentemente', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('Constituição', 'O'),
#   ('deixará', 'O'),
#   ('de', 'O'),
#   ('ser', 'O'),
#   ('Constituição', 'O'),
#   ('e', 'O'),
#   ('será', 'O'),
#   ('apenas', 'O'),
#   ('uma', 'O'),
#   ('criatividade', 'O'),
#   ('feita', 'O'),
#   ('por', 'O'),
#   ('alguns', 'O'),
#   ('legisladores', 'O'),
#   ('originários', 'O'),
#   ('e', 'O'),
#   ('por', 'O'),
#   ('intérpretes', 'O'),
#   ('sazonais', 'O'),
#   (',', 'O'),
#   ('com', 'O'),
#   ('menor', 'O'),
#   ('número', 'O'),
#   ('.', 'O')],
#  [('Assim', 'O'),
#   (',', 'O'),
#   ('continuo', 'O'),
#   ('com', 'O'),
#   ('o', 'O'),
#   ('mesmo', 'O'),
#   ('aspecto', 'O'),
#   ('de', 'O'),
#   ('sempre', 'O'),
#   ('e', 'O'),
#   ('a', 'O'),
#   ('palavra', 'O'),
#   ('“', 'O'),
#   ('aspecto', 'O'),
#   ('”', 'O'),
#   ('aqui', 'O'),
#   ('está', 'O'),
#   ('no', 'O'),
#   ('sentido', 'O'),
#   ('latino', 'O'),
#   (',', 'O'),
#   ('de', 'O'),
#   ('“', 'O'),
#   ('olhar', 'O'),
#   ('”', 'O'),
#   ('e', 'O'),
#   ('digo', 'O'),
#   ('que', 'O'),
#   ('este', 'O'),
#   ('Tribunal', 'O'),
#   ('não', 'O'),
#   ('tem', 'O'),
#   ('competência', 'O'),
#   ('para', 'O'),
#   ('julgar', 'O'),
#   ('ação', 'O'),
#   ('direta', 'O'),
#   ('de', 'O'),
#   ('inconstitucionalidade', 'O'),
#   (',', 'O'),
#   ('por', 'O'),
#   ('falta', 'O'),
#   ('de', 'O'),
#   ('previsão', 'O'),
#   ('constitucional', 'O'),
#   ('.', 'O')],
#  [('Tanto', 'O'),
#   ('é', 'O'),
#   ('verdade', 'O'),
#   ('que', 'O'),
#   ('a', 'O'),
#   ('emenda', 'O'),
#   ('constitucional', 'O'),
#   ('que', 'O'),
#   ('autorizou', 'O'),
#   ('a', 'O'),
#   ('Câmara', 'B-ORGANIZACAO'),
#   ('Legislativa', 'I-ORGANIZACAO'),
#   ('e', 'O'),
#   ('o', 'O'),
#   ('Governador', 'O'),
#   ('do', 'O'),
#   ('Distrito', 'B-LOCAL'),
#   ('Federal', 'I-LOCAL'),
#   ('de', 'O'),
#   ('serem', 'O'),
#   ('autores', 'O'),
#   ('na', 'O'),
#   ('ação', 'O'),
#   ('direta', 'O'),
#   ('de', 'O'),
#   ('inconstitucionalidade', 'O'),
#   ('junto', 'O'),
#   ('ao', 'O'),
#   ('Supremo', 'B-ORGANIZACAO'),
#   ('é', 'O'),
#   ('apenas', 'O'),
#   ('deste', 'O'),
#   ('milênio', 'O'),
#   ('.', 'O')],
#  [('Se', 'O'),
#   (',', 'O'),
#   ('para', 'O'),
#   ('eles', 'O'),
#   (',', 'O'),
#   ('foi', 'O'),
#   ('preciso', 'O'),
#   ('fazer', 'O'),
#   ('uma', 'O'),
#   ('emenda', 'O'),
#   ('constitucional', 'O'),
#   (',', 'O'),
#   ('por', 'O'),
#   ('que', 'O'),
#   ('não', 'O'),
#   ('o', 'O'),
#   ('seria', 'O'),
#   (',', 'O'),
#   ('também', 'O'),
#   (',', 'O'),
#   ('para', 'O'),
#   ('este', 'O'),
#   ('Tribunal', 'O'),
#   ('?', 'O')],
#  [('Evidentemente', 'O'),
#   (',', 'O'),
#   ('não', 'O'),
#   ('se', 'O'),
#   ('compara', 'O'),
#   ('a', 'O'),
#   ('Lei', 'B-LEGISLACAO'),
#   ('Orgânica', 'I-LEGISLACAO'),
#   ('do', 'I-LEGISLACAO'),
#   ('Distrito', 'I-LEGISLACAO'),
#   ('Federal', 'I-LEGISLACAO'),
#   ('com', 'O'),
#   ('as', 'O'),
#   ('Constituições', 'O'),
#   ('Estaduais', 'O'),
#   (',', 'O'),
#   ('porque', 'O'),
#   ('as', 'O'),
#   ('Constituições', 'O'),
#   ('Estaduais', 'O'),
#   ('têm', 'O'),
#   ('um', 'O'),
#   ('conteúdo', 'O'),
#   ('orgânico', 'O'),
#   ('e', 'O'),
#   ('holístico', 'O'),
#   ('de', 'O'),
#   ('cada', 'O'),
#   ('setor', 'O'),
#   ('dos', 'O'),
#   ('Estados', 'O'),
#   ('dentro', 'O'),
#   ('da', 'O'),
#   ('Federação', 'O'),
#   ('.', 'O')],
#  ...]

# %%
def extract_labels(filepath):
    labels = set()
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            if line.strip():
                parts = line.strip().split()
                if len(parts) >= 2:
                    label = parts[-1]
                    labels.add(label)
    return sorted(labels)

label_list = extract_labels('train.conll')

# %%
label_to_id = {label: idx for idx, label in enumerate(label_list)}
id_to_label = {idx: label for label, idx in label_to_id.items()}
num_labels = len(label_list)

# %%
label_list, num_labels
# Out:
# (['B-JURISPRUDENCIA',
#   'B-LEGISLACAO',
#   'B-LOCAL',
#   'B-ORGANIZACAO',
#   'B-PESSOA',
#   'B-TEMPO',
#   'I-JURISPRUDENCIA',
#   'I-LEGISLACAO',
#   'I-LOCAL',
#   'I-ORGANIZACAO',
#   'I-PESSOA',
#   'I-TEMPO',
#   'O'],
#  13)

# %%
from transformers import BertForTokenClassification

model = BertForTokenClassification.from_pretrained('bert-base-multilingual-cased', num_labels=num_labels)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained('bert-base-multilingual-cased')

def tokenize_and_align_labels(sentences):
    tokenized_inputs = tokenizer(
        [[token for token, label in sentence] for sentence in sentences],
        is_split_into_words=True,
        return_offsets_mapping=True,
        padding=True,
        truncation=True
    )
    labels = []
    for i, sentence in enumerate(sentences):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_ids = []
        previous_word_idx = None
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label_to_id[sentence[word_idx][1]])
            else:
                label_ids.append(label_to_id[sentence[word_idx][1]] if label_all_tokens else -100)
            previous_word_idx = word_idx
        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    return tokenized_inputs
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %%
from transformers import BertForTokenClassification, Trainer, TrainingArguments

model = BertForTokenClassification.from_pretrained('bert-base-multilingual-cased', num_labels=num_labels)

training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d14ff84d58cd> in <cell line: 0>()
#       3 model = BertForTokenClassification.from_pretrained('bert-base-multilingual-cased', num_labels=num_labels)
#       4
# ----> 5 training_args = TrainingArguments(
#       6     output_dir='./results',
#       7     evaluation_strategy="epoch",
#
# TypeError: TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'
